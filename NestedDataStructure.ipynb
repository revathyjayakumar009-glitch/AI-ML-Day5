# %%
'''
  List inside List
  Dictionaries inside List
  List as value of Dictionary
  Dictionary as a value of Dictionary
'''
# Out:
# '\n  List inside List\n  Dictionaries inside List\n  List as value of Dictionary\n  Dictionary as a value of Dictionary\n'

# %%
#List in List
matrix = [[1,0,-1],[1,-1,0],[1,-1,0]]
print(matrix)
# Out:
# [[1, 0, -1], [1, -1, 0], [1, -1, 0]]

# %%
print(matrix[0])
print(matrix[1])
print(matrix[2])
# Out:
# [1, 0, -1]
# [1, -1, 0]
# [1, -1, 0]

# %%
matrix[0][2]
# Out:
# -1

# %%
dic=[
      {'points':23,'assist' : 7},
       {'points':33,'assist': 4},
        {'points':16,'assist':11},]
print(dic)
# Out:
# [{'points': 23, 'assist': 7}, {'points': 33, 'assist': 4}, {'points': 16, 'assist': 11}]

# %%
dic[1]['points']
# Out:
# 33
