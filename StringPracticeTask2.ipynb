# %%
Str = "AI-ML Internship"
Str
# Out:
# 'AI-ML Internship'

# %%
# Reverse a String
print("Reverse of a string:",Str[::-1])
# Out:
# Reverse of a string: pihsnretnI LM-IA

# %%
#Count number of words
a=Str.count(" ") + 1
print("Number of words:",a)
# Out:
# 2

# %%
#check palindrome
if Str==Str[::-1]:
    print("Palindrome")
else:
    print("Not Palindrome")
# Out:
# Not Palindrome

# %%
#Replace Words
String = "Welcome to India"
NewString=String.replace("India","Kerala")
NewString
# Out:
# 'Welcome to Kerala'

# %%
# Count Vowels
vowels = "aeiouAEIOU"
count = 0
for char in Str:
    if char in vowels:
        count += 1
print("Number of vowels:", count)
# Out:
# Number of vowels: 5
